# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanChatha/Dev-Roadmap/blob/master/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: write Hello World program

print("Hello World")
# Out:
# Hello World

# %%
# prompt: write a program to take prompt from user and reply through google gemini using langchain and poetry

# !pip install langchain
# !pip install google-search-results
# !pip install poetry

from langchain.llms import GooglePalm
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.utilities import GoogleSearchAPIWrapper

# Set your Google Palm API key
import os
os.environ["GOOGLE_API_KEY"] = "YOUR_GOOGLE_API_KEY"

# Initialize the LLM
llm = GooglePalm(temperature=0.1)

# Create a prompt template
prompt = PromptTemplate(
    input_variables=["query"],
    template="Answer the following question: {query}"
)

# Create a chain
chain = LLMChain(llm=llm, prompt=prompt)

# Get user input
user_input = input("Enter your question: ")

# Run the chain
response = chain.run(user_input)

print(response)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# prompt: write a program to take prompt from user and reply through google gemini using langchain and poetry

# !pip install langchain
# !pip install google-search-results
# !pip install poetry

from langchain.llms import GooglePalm
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.utilities import GoogleSearchAPIWrapper

# Set your Google Palm API key
import os
os.environ["GOOGLE_API_KEY"] = "YOUR_GOOGLE_API_KEY"

# Initialize the LLM
llm = GooglePalm(temperature=0.1)

# Create a prompt template
prompt = PromptTemplate(
    input_variables=["query"],
    template="Answer the following question: {query}"
)

# Create a chain
chain = LLMChain(llm=llm, prompt=prompt)

# Get user input
user_input = input("Enter your question: ")

# Run the chain
response = chain.run(user_input)

print(response)
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e5fe6060f719> in <cell line: 7>()
#       5 get_ipython().system('pip install poetry')
#       6
# ----> 7 from langchain.llms import GooglePalm
#       8 from langchain.prompts import PromptTemplate
#       9 from langchain.chains import LLMChain
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/__init__.py in __getattr__(name)
#     543
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     546
#     547     # If not in interactive env, raise warning.
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...
